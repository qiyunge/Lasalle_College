# %%
from pathlib import Path

import matplotlib.pyplot as plt
import plotly 
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df_loan = pd.read_csv("./data/loan_cleaned.csv")
df_loan.head()
df_loan.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    str
#  1   Gender             614 non-null    str
#  2   Married            614 non-null    str
#  3   Dependents         614 non-null    str
#  4   Education          614 non-null    str
#  5   Self_Employed      614 non-null    str
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    str
#  12  Loan_Status        614 non-null    str
# dtypes: float64(4), int64(1), str(8)
# memory usage: 62.5 KB

# %%
plt.hist(df_loan["ApplicantIncome"], bins=20)
# Out:
# (array([353., 180.,  44.,  15.,  12.,   3.,   0.,   0.,   1.,   3.,   0.,
#           0.,   1.,   0.,   0.,   1.,   0.,   0.,   0.,   1.]),
#  array([  150. ,  4192.5,  8235. , 12277.5, 16320. , 20362.5, 24405. ,
#         28447.5, 32490. , 36532.5, 40575. , 44617.5, 48660. , 52702.5,
#         56745. , 60787.5, 64830. , 68872.5, 72915. , 76957.5, 81000. ]),
#  <BarContainer object of 20 artists>)

# %%
import plotly.express as px

# %%
px.histogram(df_loan, x="ApplicantIncome", nbins=50)

# %%
px.scatter(df_loan, x="Gender", y="ApplicantIncome", color="Loan_Status")

# %%
px.scatter(df_loan, x="ApplicantIncome", y="CoapplicantIncome", color="Gender",
           labels={"ApplicantIncome": "Applicant Income", "CoapplicantIncome": "Coapplicant Income"}
           )

# %%
df_loan["Gender"].value_counts()
# Out:
# Gender
# Male      500
# Female    114
# Name: count, dtype: int64

# %%
df_loan["Gender"].unique()
# Out:
# <StringArray>
# ['Male', 'Female']
# Length: 2, dtype: str

# %%
df_titanic = pd.read_csv("./data/titanic_clean.csv")

# %%
df_titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Embarked
# 0      0         A/5 21171   7.2500        S
# 1      0          PC 17599  71.2833        C
# 2      0  STON/O2. 3101282   7.9250        S
# 3      0            113803  53.1000        S
# 4      0            373450   8.0500        S

# %%
df_titanic.dtypes
px.scatter_3d(df_titanic, x="Age", y="Fare", z="Sex", color="Survived", size="Pclass",
              )
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Embarked           str
# dtype: object

# %%
px.box(df_titanic, y="Age", color="Sex")

# %%
px.box(df_titanic, y=["Age", "Fare"], color="Sex", points="outliers")

# %%
px.violin(df_titanic, y="Age", color="Sex",points=False)
