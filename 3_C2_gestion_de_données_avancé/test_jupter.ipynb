# %%
import matplotlib as plt
import pandas as pd
names = [ "John", "Jane", "Doe"
]
sex = [ "Male", "Female", "Male" ]

ages = [ 25, 30, 22 ]

df  = pd.DataFrame({
    "Name": names,  
    "Sex": sex,
    "Age": ages
})  

df

note = [ 100,70, 80]
note[0] /= 2
note
# Out:
# [50.0, 70, 80]
